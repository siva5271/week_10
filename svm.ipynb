# %% [markdown]
# # SVM classification using iris datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn import svm

# %% [markdown]
# ### Here i am using the iris datasets from sklearn to produce the necessary dataframes

# %%
iris=load_iris()
df=pd.DataFrame(data=iris.data,columns=iris.feature_names)
df["target"]=iris.target
df["target names"]=df.target.apply(lambda x:iris.target_names[x])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target target names
# ...

# %% [markdown]
# ## I am gonna plot the scatter plot to determine whether the data sets can be efficiently classified

# %%
df0=df[df['target']==0]
df1=df[df['target']==1]
df2=df[df['target']==2]
df2
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 106                4.9               2.5                4.5               1.7
# 107                7.3               2.9                6.3               1.8
# 108                6.7               2.5                5.8               1.8
# 109                7.2               3.6                6.1               2.5
# 110                6.5               3.2                5.1               2.0
# ...

# %% [markdown]
# ## setosa v/s versicolor

# %% [markdown]
# ### sepal length and sepal width

# %%
sns.scatterplot(x="sepal length (cm)",y="sepal width (cm)",data=df0)
sns.scatterplot(x="sepal length (cm)",y="sepal width (cm)",data=df1)
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %% [markdown]
# ### petal length and petal width

# %%
sns.scatterplot(x="petal length (cm)",y="petal width (cm)",data=df0)
sns.scatterplot(x="petal length (cm)",y="petal width (cm)",data=df1)
# Out:
# <Axes: xlabel='petal length (cm)', ylabel='petal width (cm)'>

# %% [markdown]
# ## setosa v/s virginica

# %% [markdown]
# ### sepal length and sepal width

# %%
sns.scatterplot(x="sepal length (cm)",y="sepal width (cm)",data=df0)
sns.scatterplot(x="sepal length (cm)",y="sepal width (cm)",data=df2)
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %% [markdown]
# ### petal length and petal width

# %%
sns.scatterplot(x="petal length (cm)",y="petal width (cm)",data=df0)
sns.scatterplot(x="petal length (cm)",y="petal width (cm)",data=df2)
# Out:
# <Axes: xlabel='petal length (cm)', ylabel='petal width (cm)'>

# %% [markdown]
# # versicolor v/s viriginica

# %% [markdown]
# ### sepal length and sepal width

# %%
sns.scatterplot(x="sepal length (cm)",y="sepal width (cm)",data=df1)
sns.scatterplot(x="sepal length (cm)",y="sepal width (cm)",data=df2)
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %% [markdown]
# ### petal length and petal width

# %%
sns.scatterplot(x="petal length (cm)",y="petal width (cm)",data=df1)
sns.scatterplot(x="petal length (cm)",y="petal width (cm)",data=df2)
# Out:
# <Axes: xlabel='petal length (cm)', ylabel='petal width (cm)'>

# %%
X=df.drop(["target","target names"],axis=1)
y=df["target"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
model=svm.SVC()
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
model.score(X_test,y_test)
# Out:
# 0.9
